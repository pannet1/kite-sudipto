# %%
input_with_common = [{'common': {'multiplier': 1}}, {'BANKNIFTY': {'underlying': 'NSE:BANKNIFTY', 'ce': -100, 'pe': 100, 'diff': 100, 'expiry': '23OCT', 'lotsize': 45, 'stoploss': 20}}, {'NIFTY': {'underlying': 'NSE:NIFTY 50', 'ce': -200, 'pe': 200, 'diff': 50, 'expiry': '23OCT', 'lotsize': 25, 'stoploss': 10}}]




result = merge_common_to_symbols(input_with_common)
print(result)
# Out:
# {'BANKNIFTY': {'underlying': 'NSE:BANKNIFTY', 'ce': -100, 'pe': 100, 'diff': 100, 'expiry': '23OCT', 'lotsize': 45, 'stoploss': 20, 'multiplier': 1}, 'NIFTY': {'underlying': 'NSE:NIFTY 50', 'ce': -200, 'pe': 200, 'diff': 50, 'expiry': '23OCT', 'lotsize': 25, 'stoploss': 10, 'multiplier': 1}}

# %%
def merge_common_to_symbols(input_with_common: list[dict]):
    common_items = {}
    output_without_common = {}

    for item in input_with_common:
        if "common" in item:
            common_items = item["common"]
        else:
            merged_item = {key: value for key, value in item.items() if key != "common"}
            merged_item.update(common_items)
            output_without_common.update(merged_item)

    return output_without_common

input_with_common = [{'BANKNIFTY': {'underlying': 'NSE:BANKNIFTY', 'ce': -100, 'pe': 100, 'diff': 100, 'expiry': '23OCT', 'lotsize': 45, 'stoploss': 20}}, {'NIFTY': {'underlying': 'NSE:NIFTY 50', 'ce': -200, 'pe': 200, 'diff': 50, 'expiry': '23OCT', 'lotsize': 25, 'stoploss': 10}}, {'common': {'multiplier': 1}}]

result = merge_common_to_symbols(input_with_common)

# Print the result
for key, value in result.items():
    print(key)
    print(value)
# Out:
# BANKNIFTY
# {'underlying': 'NSE:BANKNIFTY', 'ce': -100, 'pe': 100, 'diff': 100, 'expiry': '23OCT', 'lotsize': 45, 'stoploss': 20}
# NIFTY
# {'underlying': 'NSE:NIFTY 50', 'ce': -200, 'pe': 200, 'diff': 50, 'expiry': '23OCT', 'lotsize': 25, 'stoploss': 10}

# %%
from io import BytesIO
def get_instrument_details():
    import requests 
    url = 'https://api.kite.trade/instruments'
    r = requests.get(url, allow_redirects=True)
    # open('instruments.csv', 'wb').write(r.content)
    import pandas as pd
    df = df = pd.read_csv(BytesIO(r.content))
    return df

o = get_instrument_details()
o.head()
# Out:
#    instrument_token  exchange_token       tradingsymbol    name  last_price
# 0         537733638         2100522  EURINR23DEC83.25CE  EURINR           0  \
# 1         537730310         2100509  EURINR23DEC83.25PE  EURINR           0
# 2         537617158         2100067   EURINR23DEC83.5CE  EURINR           0
# 3         537614342         2100056   EURINR23DEC83.5PE  EURINR           0
# 4         537747718         2100577  EURINR23DEC83.75CE  EURINR           0
#
#        expiry  strike  tick_size  lot_size instrument_type  segment exchange
# 0  2023-12-27   83.25     0.0025         1              CE  BCD-OPT      BCD
# 1  2023-12-27   83.25     0.0025         1              PE  BCD-OPT      BCD
# 2  2023-12-27   83.50     0.0025         1              CE  BCD-OPT      BCD
# 3  2023-12-27   83.50     0.0025         1              PE  BCD-OPT      BCD
# 4  2023-12-27   83.75     0.0025         1              CE  BCD-OPT      BCD

# %%
import pandas as pd

df = pd.read_csv("instruments.csv")
df.head()
# Out:
#    instrument_token  exchange_token       tradingsymbol    name  last_price
# 0         537733638         2100522  EURINR23DEC83.25CE  EURINR           0  \
# 1         537730310         2100509  EURINR23DEC83.25PE  EURINR           0
# 2         537617158         2100067   EURINR23DEC83.5CE  EURINR           0
# 3         537614342         2100056   EURINR23DEC83.5PE  EURINR           0
# 4         537747718         2100577  EURINR23DEC83.75CE  EURINR           0
#
#        expiry  strike  tick_size  lot_size instrument_type  segment exchange
# 0  2023-12-27   83.25     0.0025         1              CE  BCD-OPT      BCD
# 1  2023-12-27   83.25     0.0025         1              PE  BCD-OPT      BCD
# 2  2023-12-27   83.50     0.0025         1              CE  BCD-OPT      BCD
# 3  2023-12-27   83.50     0.0025         1              PE  BCD-OPT      BCD
# 4  2023-12-27   83.75     0.0025         1              CE  BCD-OPT      BCD

# %%
df[df['tradingsymbol']== 'MIDCPNIFTY23OCT10000CE' ]['instrument_token'].to_list()
# Out:
# [13353730]

# %%
df[df['tradingsymbol']== 'MIDCPNIFTY23OCT10000CE' ]
# Out:
#        instrument_token  exchange_token           tradingsymbol        name
# 70119          13353730           52163  MIDCPNIFTY23OCT10000CE  MIDCPNIFTY  \
#
#        last_price      expiry   strike  tick_size  lot_size instrument_type
# 70119           0  2023-10-30  10000.0       0.05        75              CE  \
#
#        segment exchange
# 70119  NFO-OPT      NFO

# %%
cookies = [{'name': 'kf_session', 'value': 'xXwZDRucMKTDzdeVumnEqcRSNBJp4zH5', 'domain': 'kite.zerodha.com', 'path': '/', 'expires': -1, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': '_cfuvid', 'value': 'dNc44UixJFibVmcYke2eKO8DHwuucUbLMyOGR_oDhhQ-1697375555556-0-604800000', 'domain': '.zerodha.com', 'path': '/', 'expires': -1, 'httpOnly': True, 'secure': True, 'sameSite': 'None'}, {'name': 'user_id', 'value': 'CP4842', 'domain': 'kite.zerodha.com', 'path': '/', 'expires': -1, 'httpOnly': False, 'secure': True, 'sameSite': 'None'}, {'name': 'public_token', 'value': 'NyfbG4naqcuMmqAKGpyvh9BomVRdU0Cm', 'domain': '.zerodha.com', 'path': '/', 'expires': -1, 'httpOnly': False, 'secure': True, 'sameSite': 'None'}, {'name': 'enctoken', 'value': 'aeagNM+23dI9lyFrMvEjK84a66dqxLWjE2aW1E5BrxPbY34+MiHvwcTrn0Xria51huBIipQwNTrAZ2EjbTraKO6TX1d5/XF39fEjH/aViSgNVrum/4M5Mg==', 'domain': 'kite.zerodha.com', 'path': '/', 'expires': -1, 'httpOnly': False, 'secure': True, 'sameSite': 'None'}]


import pprint
pprint.pprint(cookies)
# Out:
# [{'domain': 'kite.zerodha.com',
#   'expires': -1,
#   'httpOnly': True,
#   'name': 'kf_session',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'xXwZDRucMKTDzdeVumnEqcRSNBJp4zH5'},
#  {'domain': '.zerodha.com',
#   'expires': -1,
#   'httpOnly': True,
#   'name': '_cfuvid',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'dNc44UixJFibVmcYke2eKO8DHwuucUbLMyOGR_oDhhQ-1697375555556-0-604800000'},
#  {'domain': 'kite.zerodha.com',
#   'expires': -1,
#   'httpOnly': False,
#   'name': 'user_id',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'CP4842'},
#  {'domain': '.zerodha.com',
#   'expires': -1,
#   'httpOnly': False,
#   'name': 'public_token',
#   'path': '/',
#   'sameSite': 'None',
#   'secure': True,
#   'value': 'NyfbG4naqcuMmqAKGpyvh9BomVRdU0Cm'},
#  {'domain': 'kite.zerodha.com',
#   'expires': -1,
#   'httpOnly': False,
#   'name': 'enctoken',
#   'path': '/',
#   'sameSite': 'None',
# ...
